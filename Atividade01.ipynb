# %% [markdown]
# <a href="https://colab.research.google.com/github/ThaisKheyla/R-Python-lab/blob/main/Atividade01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10
print(a)
# Out:
# 10

# %%
print('teste')
# Out:
# teste

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Carregar dataset
df = sns.load_dataset('iris')

# Histograma
sns.histplot(df['sepal_length'], kde=True)
plt.title('Distribuição do comprimento da sépala')
plt.show()

# %%
# Out:
# <div id='f9e19b19-8147-4775-9e64-c7f164aa6130'></div>

# %%
# !pip install matplotlib-venn
